# %% [markdown]
# ### Jupyter Notebook ver. of Implementation

# %%
"""input parameters"""

r = 1 # 1: Schools_Attended, 2: Work_For, 3: Live_In, 4: Top_Member_Employees
t = 0.7 # extraction confidence threshold
q = "mark zuckerberg harvard"  # seed query
k = 17  # number of tuples requested

API_key = "****"
search_engine_ID = "****"

# %%
"""libraries and functions"""

from googleapiclient.discovery import build
import requests
from bs4 import BeautifulSoup
from spacy_help_functions import extract_relations
import spacy
from spanbert import SpanBERT #Note:  pip install torchvision,  pip3 install boto3
import multiprocessing
import time
import signal
import unicodedata

def initiate_query(query: str) -> dict:
    '''
    Start a query using Google JSON API
    query: user query string
    return query result in its raw format (JSON in Python dict format)
    '''

    # q: query and cx is our search engine ID 
    res = service.cse().list(
        q=query,
        cx=search_engine_ID,
    ).execute()

    return res

#beautiful soup function
def extract_plain_text(link: str) -> str:

    res = requests.get(link) #need to iterate top 10 links?
    content = res.content
    soup = BeautifulSoup(content, "html.parser")
    text = soup.find_all(text=True)

    plain_text = ''
    # filter out elements that we don't want
    blacklist = [
        '[document]',
        'noscript',
        'header',
        'html',
        'meta',
        'head', 
        'input', 
        'script',
        'style',
        'title']

    for t in text:
        if t.parent.name not in blacklist:
            plain_text += '{} '.format(t)

    # remove unwanted unicode chars
    plain_text = unicodedata.normalize("NFKD", plain_text)
    
    return plain_text


def truncate_plain_text(plain_text: str, cap: int=20000):
    """
    cap: truncate any char over cap
    """

    # print('length of plain text: ', len(plain_text))
    if len(plain_text) > cap:
        plain_text = plain_text[:cap]
        # print('truncated to {} characters'.format(len(plain_text)))

    return plain_text

# %%
"""main process"""
X = []  # the list to hold extracted relations

#########################################################################
# Schools_Attended: Subject: PERSON, Object: ORGANIZATION
# Work_For: Subject: PERSON, Object: ORGANIZATION
# Live_In: Subject: PERSON, Object: one of LOCATION, CITY, STATE_OR_PROVINCE, or COUNTRY
# Top_Member_Employees: Subject: ORGANIZATION, Object: PERSON
#########################################################################
entities_of_interest_ls = [["ORGANIZATION", "PERSON"], 
                            ["ORGANIZATION", "PERSON"], 
                            ["ORGANIZATION", "PERSON", "LOCATION", "CITY", "STATE_OR_PROVINCE", "COUNTRY"], 
                            ["ORGANIZATION", "PERSON"]]
# for Spacy; decide which entities to extract
entities_of_interest = entities_of_interest_ls[r-1] # don't forget to -1 for correct list index

# for filter SpanBERT predicted results, keeping only the targeted relations
relation_ls = ('per:schools_attended', 'per:employee_of', 'per:cities_of_residence', 'org:top_members/employees')   # the four relations that we are interested in
target_rel = relation_ls[r-1]

num_extracted = 0   # number of already extracted relations
prev_url = []
service = build("customsearch", "v1",
              developerKey=API_key) 

num_of_iter = 0

while num_extracted < k:

    """issue a query"""
    print('Issuing a query: ', q)
    num_of_iter += 1
 
    '''Evan: I think time out is for beautiful soup to retrieve each webpage url???'''
    #Wait 20 secs to retrieve webpage
    #signal.alarm(20)    
    #try:
    q_res = initiate_query(q)
    #except Exception:
    #    continue
    #else:
        # Reset the alarm
    #    signal.alarm(0)
    
    """use beautifulsoup to extract plain text"""
    for web_page in q_res['items']:
        duplicate = False

        link = web_page['link']

        # skip already seen URL
        if link in prev_url:
            continue
        else:
            prev_url.append(link)

        #BeautifulSoup Timeout if more than 20 seconds 
        signal.alarm(20)    
        try:
            plain_text = extract_plain_text(link)
        except Exception:
            continue
        else:
            # Reset the alarm
            signal.alarm(0)

        # truncate to 20000 characters
        plain_text = truncate_plain_text(plain_text, cap=20000)

        """feed plain text into Spacy+BERT process"""
        # Load spacy model
        nlp = spacy.load("en_core_web_lg")  

        # Apply spacy model to raw text (to split to sentences, tokenize, extract entities etc.)
        doc = nlp(plain_text)  

        # Load pre-trained SpanBERT model
        spanbert = SpanBERT("./pretrained_spanbert")  

        # Extract relations
        relations = extract_relations(doc, spanbert, entities_of_interest, conf=t, r=r)
        # print("Relations: {}".format(dict(relations)))

        # keep only target relations
        # each key in "relations" is a tuple of (subject, relation type, object)
        # and value is the confidence score for that relation tuple
        for rel in relations.keys():
            try:
                if rel[1] != target_rel:
                    continue
                
                #TO DO: only append to X if tuple not already exist OR confidence level is higher than already exist 
                # don't need this conditional check bc suhc filtering is done in the extract_relation()
                # if relations[rel] >= t:
                # use lower case uniformally

                #Check for duplicates in X
                for item in X:
                    if item["subject"] == rel[0].lower():
                        if item["object"] == rel[2].lower():
                            if item["confidence"] > relations[rel]:
                                duplicate = True
                                break
                            elif item["confidence"] < relations[rel]:
                                X.pop(item) 
                                duplicate = False
                                break
                                
                if duplicate == False:
                    X.append({
                        'confidence': relations[rel],
                        'subject': rel[0].lower(),
                        'object': rel[2].lower()
                    })
                else:
                    continue

                num_extracted += 1
                if num_extracted >= k:
                    break

            except Exception:
                # sometimes there are weird keys such as integers so added this to avoid error
                pass

        if num_extracted >= k:
            break

        
        print('Finish processing webpage: {}\nCurrent X: {}\nCurrent number of relations: {}'.format(web_page['link'], X, len(X)))

    # Update query q if k not reached yet 
    if num_extracted < k:
        print('============================\nUpdating query...\n============================\n')
        X.sort(key = lambda tup: tup.get("confidence"),reverse=True)
        # convert query string, q, into a list of words, and turn into lower case
        q_words = q.split()
        q_words = [wd.lower() for wd in q_words]
        # print('q_words: ', q_words)
        qlen_before = len(q_words)
        for rel in X:
            if rel["object"] not in q_words:
                if rel["subject"] not in q_words:
                    # print('Extending: obj: {}, sub: {}'.format(rel['object'], rel['subject']))
                    q_words.extend([rel["object"], rel["subject"]])
                    q = ' '.join(q_words)
                    print('Query has been updated to: ', q)
                    break
            else:
                continue
        # no valid relation tuple to augment the query
        if len(q_words) == qlen_before:
            print('Unable to update query (no valid relation tuple). Quitting...\n')
            break
        

"""print results"""
print('--------------Result----------------')
print('Confidence\t|Subject\t|Object\t\n')
X.sort(key = lambda tup: tup.get("confidence"),reverse=True) #sort X in DESC confidence level
for relation in X:
    print('Confidence: {}\tSubject: {}\tObject: {}'.format(relation["confidence"], relation["subject"], relation["object"]))

print("\nNumber of relations: \n".format(len(X)))
print("\nTotal number of iterations: ", num_of_iter)
# Out:
# Issuing a query:  megan repinoe redding
# Loading pre-trained spanBERT from ./pretrained_spanbert
# Total # sentences = 48
# processing sentence: News   Sports
# 	Entity pairs:  []
#
# processing sentence: Opinion   Business
# 	Entity pairs:  []
#
# processing sentence: Entertainment   Lifestyle   E-Edition   Legals
# 	Entity pairs:  []
#
# processing sentence: Best of the North State
# 	Entity pairs:  []
#
# processing sentence: After World Cup win — and local controversy — Megan Rapinoe still praises 'hometown love'  Alayna Shulman Redding View Comments View Comments Shasta County residents might be divided over homegrown soccer superstar Megan Rapinoe's outspoken political beliefs, but the 34-year-old still considers local support "the best kind of love" after leading her country to World Cup victory over the Netherlands Sunday.
# 	Entity pairs:  [(['Megan', 'Rapinoe', 'still', 'praises', "'", 'hometown', 'love', "'", ' ', 'Alayna', 'Shulman', 'Redding', 'View', 'Comments', 'View', 'Comments', 'Shasta', 'County', 'residents', 'might', 'be', 'divided', 'over', 'homegrown', 'soccer', 'superstar', 'Megan', 'Rapinoe', "'s", 'outspoken', 'political', 'beliefs', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Alayna Shulman Redding View Comments View Comments', 'PERSON', (9, 15))), (['Megan', 'Rapinoe', 'still', 'praises', "'", 'hometown', 'love', "'", ' ', 'Alayna', 'Shulman', 'Redding', 'View', 'Comments', 'View', 'Comments', 'Shasta', 'County', 'residents', 'might', 'be', 'divided', 'over', 'homegrown', 'soccer', 'superstar', 'Megan', 'Rapinoe', "'s", 'outspoken', 'political', 'beliefs', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Shasta County', 'LOCATION', (16, 17))), ([' ', 'Alayna', 'Shulman', 'Redding', 'View', 'Comments', 'View', 'Comments', 'Shasta', 'County', 'residents', 'might', 'be', 'divided', 'over', 'homegrown', 'soccer', 'superstar', 'Megan', 'Rapinoe', "'s", 'outspoken', 'political', 'beliefs', ','], ('Alayna Shulman Redding View Comments View Comments', 'PERSON', (1, 7)), ('Megan Rapinoe', 'PERSON', (18, 19))), ([' ', 'Alayna', 'Shulman', 'Redding', 'View', 'Comments', 'View', 'Comments', 'Shasta', 'County', 'residents', 'might', 'be', 'divided', 'over', 'homegrown', 'soccer', 'superstar', 'Megan', 'Rapinoe', "'s", 'outspoken', 'political', 'beliefs', ','], ('Shasta County', 'LOCATION', (8, 9)), ('Megan Rapinoe', 'PERSON', (18, 19)))]
#
# processing sentence: More: USWNT soccer: How can I stream the ticker-tape parade in NYC's Canyon of Heroes?
# 	Entity pairs:  [(['More', ':', 'USWNT', 'soccer', ':', 'How', 'can', 'I', 'stream', 'the', 'ticker', '-', 'tape', 'parade', 'in', 'NYC', "'s", 'Canyon', 'of', 'Heroes', '?'], ('USWNT', 'ORGANIZATION', (2, 2)), ('NYC', 'LOCATION', (15, 15)))]
#
# processing sentence: In an energetic Instagram story Rapinoe posted celebrating the win, one shot shows the Record Searchlight's Monday cover page that featured a full-page picture of her after the historic win.
# 	Entity pairs:  [(['In', 'an', 'energetic', 'Instagram', 'story', 'Rapinoe', 'posted', 'celebrating', 'the', 'win', ','], ('Instagram', 'ORGANIZATION', (3, 3)), ('Rapinoe', 'PERSON', (5, 5))), (['In', 'an', 'energetic', 'Instagram', 'story', 'Rapinoe', 'posted', 'celebrating', 'the', 'win', ',', 'one', 'shot', 'shows', 'the', 'Record', 'Searchlight', "'s", 'Monday', 'cover', 'page', 'that', 'featured', 'a', 'full', '-'], ('Instagram', 'ORGANIZATION', (3, 3)), ('Searchlight', 'PERSON', (16, 16))), (['In', 'an', 'energetic', 'Instagram', 'story', 'Rapinoe', 'posted', 'celebrating', 'the', 'win', ',', 'one', 'shot', 'shows', 'the', 'Record', 'Searchlight', "'s", 'Monday', 'cover', 'page', 'that', 'featured', 'a', 'full', '-'], ('Rapinoe', 'PERSON', (5, 5)), ('Searchlight', 'PERSON', (16, 16)))]
#
# processing sentence: Rapinoe captioned the picture of the newspaper "Hometown love is the best kind of love," followed by four affectionate-looking emojis surrounded by hearts.
# 	Entity pairs:  []
#
# processing sentence: It's an especially significant statement considering the scorn some locals have heaped upon Rapinoe for her refusal to visit President Donald Trump and her kneeling in protest of police brutality during the national anthem.
# 	Entity pairs:  [(['It', "'s", 'an', 'especially', 'significant', 'statement', 'considering', 'the', 'scorn', 'some', 'locals', 'have', 'heaped', 'upon', 'Rapinoe', 'for', 'her', 'refusal', 'to', 'visit', 'President', 'Donald', 'Trump', 'and', 'her', 'kneeling', 'in', 'protest', 'of', 'police', 'brutality', 'during', 'the', 'national', 'anthem', '.'], ('Rapinoe', 'PERSON', (14, 14)), ('Donald Trump', 'PERSON', (21, 22)))]
#
# processing sentence: Rapinoe — now famously — said last month she wouldn't be "going to the (expletive) White House" if invited.
# 	Entity pairs:  [(['Rapinoe', '—', 'now', 'famously', '—', 'said', 'last', 'month', 'she', 'would', "n't", 'be', '"', 'going', 'to', 'the', '(', 'expletive', ')', 'White', 'House', '"'], ('Rapinoe', 'PERSON', (0, 0)), ('White House', 'ORGANIZATION', (19, 20)))]
#
# processing sentence: Rapinoe apologized for her language but stood by her statement, and Trump took to Twitter to blast her.
# 	Entity pairs:  [(['Rapinoe', 'apologized', 'for', 'her', 'language', 'but', 'stood', 'by', 'her', 'statement', ',', 'and', 'Trump', 'took', 'to', 'Twitter', 'to', 'blast', 'her', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('Trump', 'PERSON', (12, 12)))]
#
# processing sentence:
# 	Entity pairs:  []
#
# processing sentence: More: From Megan Rapinoe's yearbook: How she handled the national anthem and teamwork as a teen Those types of comments have put the outspoken athlete, in some ways, at odds with her conservative home county, where  even some who knew Rapinoe growing up have distanced themselves as her star continues to rise throughout the rest of the world .
# 	Entity pairs:  []
#
# processing sentence: The Record Searchlight has even gotten letters to the editor decrying Rapinoe's perceived lack of patriotism.
# 	Entity pairs:  [(['The', 'Record', 'Searchlight', 'has', 'even', 'gotten', 'letters', 'to', 'the', 'editor', 'decrying', 'Rapinoe', "'s", 'perceived', 'lack', 'of', 'patriotism', '.'], ('The Record Searchlight', 'PERSON', (0, 2)), ('Rapinoe', 'PERSON', (11, 11)))]
#
# processing sentence:  Responding to  her critics,  Rapinoe last week said to reporters , “I think that I’m particularly and uniquely and very deeply American.
# 	Entity pairs:  []
#
# processing sentence: “If we want to talk about the ideals that we stand for, the song and the anthem, and what we were founded on, I think I’m extremely American," she said.
# 	Entity pairs:  []
#
# processing sentence: And while Rapinoe doesn't reflect the political beliefs of most of her home county, about 300 of its residents still gathered in Redding Sunday for  a watch party of Rapinoe's final game in this year's Women's World Cup .
# 	Entity pairs:  [(['about', '300', 'of', 'its', 'residents', 'still', 'gathered', 'in', 'Redding', 'Sunday', 'for', ' ', 'a', 'watch', 'party', 'of', 'Rapinoe', "'s", 'final', 'game', 'in', 'this', 'year', "'s", 'Women', "'s", 'World', 'Cup', '.'], ('Redding', 'LOCATION', (8, 8)), ('Rapinoe', 'PERSON', (16, 16))), (['about', '300', 'of', 'its', 'residents', 'still', 'gathered', 'in', 'Redding', 'Sunday', 'for', ' ', 'a', 'watch', 'party', 'of', 'Rapinoe', "'s", 'final', 'game', 'in', 'this', 'year', "'s", 'Women', "'s", 'World', 'Cup', '.'], ('Redding', 'LOCATION', (8, 8)), ("Women's World Cup", 'ORGANIZATION', (24, 27))), (['about', '300', 'of', 'its', 'residents', 'still', 'gathered', 'in', 'Redding', 'Sunday', 'for', ' ', 'a', 'watch', 'party', 'of', 'Rapinoe', "'s", 'final', 'game', 'in', 'this', 'year', "'s", 'Women', "'s", 'World', 'Cup', '.'], ('Rapinoe', 'PERSON', (16, 16)), ("Women's World Cup", 'ORGANIZATION', (24, 27)))]
#
# processing sentence: That comes after — when she helped lead the team to victory in 2015 — the city even named a street in her honor and held "Megan Rapinoe Day.
# 	Entity pairs:  []
#
# processing sentence: "
# 	Entity pairs:  []
#
# processing sentence: Rapinoe's father, Jim Rapinoe, told the Mercury News recently that he's a veteran who voted for Trump, but he's still "really proud of the political thing with her."
# 	Entity pairs:  [(['Rapinoe', "'s", 'father', ',', 'Jim', 'Rapinoe', ','], ('Rapinoe', 'PERSON', (0, 0)), ('Jim Rapinoe', 'PERSON', (4, 5))), (['Rapinoe', "'s", 'father', ',', 'Jim', 'Rapinoe', ',', 'told', 'the', 'Mercury', 'News', 'recently', 'that', 'he', "'s", 'a', 'veteran', 'who', 'voted', 'for', 'Trump', ','], ('Rapinoe', 'PERSON', (0, 0)), ('Mercury News', 'ORGANIZATION', (9, 10))), (['Rapinoe', "'s", 'father', ',', 'Jim', 'Rapinoe', ',', 'told', 'the', 'Mercury', 'News', 'recently', 'that', 'he', "'s", 'a', 'veteran', 'who', 'voted', 'for', 'Trump', ','], ('Rapinoe', 'PERSON', (0, 0)), ('Trump', 'PERSON', (20, 20))), (['Jim', 'Rapinoe', ',', 'told', 'the', 'Mercury', 'News', 'recently', 'that', 'he', "'s", 'a', 'veteran', 'who', 'voted', 'for', 'Trump', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Mercury News', 'ORGANIZATION', (5, 6))), (['Jim', 'Rapinoe', ',', 'told', 'the', 'Mercury', 'News', 'recently', 'that', 'he', "'s", 'a', 'veteran', 'who', 'voted', 'for', 'Trump', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Trump', 'PERSON', (16, 16))), (['told', 'the', 'Mercury', 'News', 'recently', 'that', 'he', "'s", 'a', 'veteran', 'who', 'voted', 'for', 'Trump', ','], ('Mercury News', 'ORGANIZATION', (2, 3)), ('Trump', 'PERSON', (13, 13)))]
#
# processing sentence:  "She's got her stances, and she is willing to fight for them and she is willing to sacrifice it all.
# 	Entity pairs:  []
#
# processing sentence: When she did the kneeling thing, that could have been the end of her career," he told the newspaper.
# 	Entity pairs:  []
#
# processing sentence:
# 	Entity pairs:  []
#
# processing sentence: Despite those political clashes within a community that's largely conservative, Rapinoe touched on her loyalty to Redding in an ESPN interview last year.
# 	Entity pairs:  [(['Rapinoe', 'touched', 'on', 'her', 'loyalty', 'to', 'Redding', 'in', 'an', 'ESPN', 'interview', 'last', 'year', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('Redding', 'LOCATION', (6, 6))), (['Rapinoe', 'touched', 'on', 'her', 'loyalty', 'to', 'Redding', 'in', 'an', 'ESPN', 'interview', 'last', 'year', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('ESPN', 'ORGANIZATION', (9, 9))), (['Rapinoe', 'touched', 'on', 'her', 'loyalty', 'to', 'Redding', 'in', 'an', 'ESPN', 'interview', 'last', 'year', '.'], ('Redding', 'LOCATION', (6, 6)), ('ESPN', 'ORGANIZATION', (9, 9)))]
#
# processing sentence:  “I feel like Redding is kind of this underdog, hard-working, blue-collar, is-what-it-is kind of town, and I try to take that with me,” Rapinoe told ESPN.
# 	Entity pairs:  [(['Rapinoe', 'told', 'ESPN', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('ESPN', 'ORGANIZATION', (2, 2)))]
#
# processing sentence: “I never want to just say,  ‘Oh, I’m from California.’
# 	Entity pairs:  []
#
# processing sentence: I’m not from California .
# 	Entity pairs:  []
#
# processing sentence: I’m from Redding.
# 	Entity pairs:  []
#
# processing sentence: For me, that means something.”
# 	Entity pairs:  []
#
# processing sentence: More: The 5 digital benefits of a Record Searchlight subscription More: From Megan Rapinoe's yearbook: How she handled the national anthem and teamwork as a teen More: Redding crowd cheers Rapinoe and the U.S. soccer team More: USWNT soccer: What is a ticker-tape parade in NYC's Canyon of Heroes?
# 	Entity pairs:  [(['From', 'Megan', 'Rapinoe', "'s", 'yearbook', ':', 'How', 'she', 'handled', 'the', 'national', 'anthem', 'and', 'teamwork', 'as', 'a', 'teen', 'More', ':', 'Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ("Megan Rapinoe's", 'PERSON', (1, 3)), ('Redding', 'LOCATION', (19, 19))), (['From', 'Megan', 'Rapinoe', "'s", 'yearbook', ':', 'How', 'she', 'handled', 'the', 'national', 'anthem', 'and', 'teamwork', 'as', 'a', 'teen', 'More', ':', 'Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ("Megan Rapinoe's", 'PERSON', (1, 3)), ('Rapinoe', 'PERSON', (22, 22))), (['From', 'Megan', 'Rapinoe', "'s", 'yearbook', ':', 'How', 'she', 'handled', 'the', 'national', 'anthem', 'and', 'teamwork', 'as', 'a', 'teen', 'More', ':', 'Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ("Megan Rapinoe's", 'PERSON', (1, 3)), ('U.S.', 'LOCATION', (25, 25))), (['From', 'Megan', 'Rapinoe', "'s", 'yearbook', ':', 'How', 'she', 'handled', 'the', 'national', 'anthem', 'and', 'teamwork', 'as', 'a', 'teen', 'More', ':', 'Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':'], ("Megan Rapinoe's", 'PERSON', (1, 3)), ('USWNT', 'ORGANIZATION', (30, 30))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ('Redding', 'LOCATION', (0, 0)), ('Rapinoe', 'PERSON', (3, 3))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ('Redding', 'LOCATION', (0, 0)), ('U.S.', 'LOCATION', (6, 6))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':'], ('Redding', 'LOCATION', (0, 0)), ('USWNT', 'ORGANIZATION', (11, 11))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':', 'What', 'is', 'a', 'ticker', '-', 'tape', 'parade', 'in', 'NYC', "'s", 'Canyon', 'of', 'Heroes', '?'], ('Redding', 'LOCATION', (0, 0)), ('NYC', 'LOCATION', (22, 22))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':'], ('Rapinoe', 'PERSON', (3, 3)), ('U.S.', 'LOCATION', (6, 6))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':'], ('Rapinoe', 'PERSON', (3, 3)), ('USWNT', 'ORGANIZATION', (11, 11))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':', 'What', 'is', 'a', 'ticker', '-', 'tape', 'parade', 'in', 'NYC', "'s", 'Canyon', 'of', 'Heroes', '?'], ('Rapinoe', 'PERSON', (3, 3)), ('NYC', 'LOCATION', (22, 22))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':'], ('U.S.', 'LOCATION', (6, 6)), ('USWNT', 'ORGANIZATION', (11, 11))), (['Redding', 'crowd', 'cheers', 'Rapinoe', 'and', 'the', 'U.S.', 'soccer', 'team', 'More', ':', 'USWNT', 'soccer', ':', 'What', 'is', 'a', 'ticker', '-', 'tape', 'parade', 'in', 'NYC', "'s", 'Canyon', 'of', 'Heroes', '?'], ('U.S.', 'LOCATION', (6, 6)), ('NYC', 'LOCATION', (22, 22))), (['USWNT', 'soccer', ':', 'What', 'is', 'a', 'ticker', '-', 'tape', 'parade', 'in', 'NYC', "'s", 'Canyon', 'of', 'Heroes', '?'], ('USWNT', 'ORGANIZATION', (0, 0)), ('NYC', 'LOCATION', (11, 11)))]
#
# processing sentence: More: Megan Rapinoe's feud with Trump draws mixed reactions in her hometown Shasta County Alayna Shulman covers a little bit of everything for the Record Searchlight.
# 	Entity pairs:  [(['More', ':', 'Megan', 'Rapinoe', "'s", 'feud', 'with', 'Trump', 'draws', 'mixed', 'reactions', 'in', 'her', 'hometown', 'Shasta', 'County', 'Alayna', 'Shulman', 'covers', 'a', 'little', 'bit', 'of', 'everything', 'for', 'the', 'Record', 'Searchlight', '.'], ("Megan Rapinoe's", 'PERSON', (2, 4)), ('Trump', 'PERSON', (7, 7))), (['More', ':', 'Megan', 'Rapinoe', "'s", 'feud', 'with', 'Trump', 'draws', 'mixed', 'reactions', 'in', 'her', 'hometown', 'Shasta', 'County', 'Alayna', 'Shulman', 'covers', 'a', 'little', 'bit', 'of', 'everything', 'for', 'the', 'Record', 'Searchlight', '.'], ("Megan Rapinoe's", 'PERSON', (2, 4)), ('Shasta County Alayna', 'LOCATION', (14, 16))), (['More', ':', 'Megan', 'Rapinoe', "'s", 'feud', 'with', 'Trump', 'draws', 'mixed', 'reactions', 'in', 'her', 'hometown', 'Shasta', 'County', 'Alayna', 'Shulman', 'covers', 'a', 'little', 'bit', 'of', 'everything', 'for', 'the', 'Record', 'Searchlight', '.'], ('Trump', 'PERSON', (7, 7)), ('Shasta County Alayna', 'LOCATION', (14, 16)))]
#
# processing sentence: In particular, she loves writing about  the issues of this community  through  long-form storytelling .
# 	Entity pairs:  []
#
# processing sentence: Her work often centers on local  crime ,  features  and  politics , and has won awards for best writing, best business coverage and best investigative reporting in the California News Publishers Association's Better Newspapers Contest.
# 	Entity pairs:  []
#
# processing sentence: Follow her on Twitter ( @ashulman_RS ), call her at 530-225-8372 and, to support her work, please  subscribe .
# 	Entity pairs:  []
#
# processing sentence:  View Comments View Comments About Us   Staff Directory
# 	Entity pairs:  []
#
# processing sentence: Careers   Accessibility Support   Site Map
# 	Entity pairs:  []
#
# processing sentence: Legals   Our Ethical Principles   Terms of Service
# 	Entity pairs:  []
#
# processing sentence: Privacy Policy   Your California Privacy Rights / Privacy Policy Do Not Sell My Info / Cookie Policy Contact Us   Support Local Businesses
# 	Entity pairs:  []
#
# processing sentence: Advertise Your Business   Advertising Terms and Conditions
# 	Entity pairs:  []
#
# processing sentence: Buy and Sell   Licensing & Reprints
# 	Entity pairs:  []
#
# processing sentence: Help Center
# 	Entity pairs:  []
#
# processing sentence: Subscriber Guide
# 	Entity pairs:  []
#
# processing sentence: My Account   Give Feedback Subscribe Today   Newsletters   Mobile Apps   Facebook   Twitter
# 	Entity pairs:  []
#
# processing sentence: E-Edition   Storytellers   Archives
# 	Entity pairs:  []
#
# processing sentence: RSS Feeds Jobs
# 	Entity pairs:  []
#
# processing sentence: Cars   Homes   Classifieds
# 	Entity pairs:  []
#
# processing sentence: Education   Reviewed   USA TODAY Sports+   10Best   Reach Local © 2022 www.redding.com.
# 	Entity pairs:  []
#
# processing sentence: All rights reserved.
# 	Entity pairs:  []
#
# Finish processing webpage: https://www.redding.com/story/news/local/2019/07/08/after-world-cup-win-and-local-controversy-megan-rapinoe-still-praises-hometown-love/1679235001/
# Current X: []
# Current number of relations: 0
# Loading pre-trained spanBERT from ./pretrained_spanbert
# Total # sentences = 276
# processing sentence:
#
#
#
#
#   Google Tag Manager (noscript)
#
#
# 	Entity pairs:  []
#
# processing sentence: End Google Tag Manager (noscript)
#
#  Close Menu News
#
#  News
#
# 	Entity pairs:  []
#
# processing sentence: Latest Headlines
#
# 	Entity pairs:  []
#
# processing sentence: Crime and Public Safety
#  Business
#
# 	Entity pairs:  []
#
# processing sentence: Real Estate News
#
# 	Entity pairs:  []
#
# processing sentence: Housing
#  Economy
#
# 	Entity pairs:  []
#
# processing sentence: California News
#
# 	Entity pairs:  []
#
# processing sentence: National News
#  World News
#  Politics
#  Technology
#
# 	Entity pairs:  []
#
# processing sentence: Education
#
# 	Entity pairs:  []
#
# processing sentence: Environment
#
# 	Entity pairs:  []
#
# processing sentence: Science
#  Health
#
# 	Entity pairs:  []
#
# processing sentence: Mr. Roadshow
#
# 	Entity pairs:  []
#
# processing sentence: Obituaries in the News
#  SiliconValley.com
# 	Entity pairs:  []
#
# processing sentence:
#
# 	Entity pairs:  []
#
# processing sentence: Transportation
#
# 	Entity pairs:  []
#
# processing sentence: The Cannifornian
#
#
#  Local
#
#  Local News Map
#  Bay Area
#
# 	Entity pairs:  []
#
# processing sentence: San Jose
#
# 	Entity pairs:  []
#
# processing sentence: Santa Clara County
#  Peninsula
#
# 	Entity pairs:  []
#
# processing sentence: San Mateo County
#  Alameda County
#
# 	Entity pairs:  []
#
# processing sentence: Santa Cruz County
#
# 	Entity pairs:  []
#
# processing sentence: Sal Pizarro
#
# 	Entity pairs:  []
#
# processing sentence: Local Obituaries
#  Place an Obituary
#
#
#  Opinion
#
#  Opinion
#
# 	Entity pairs:  []
#
# processing sentence: Editorials
#
# 	Entity pairs:  []
#
# processing sentence: Opinion Columnists
#  Letters to the Editor
#
# 	Entity pairs:  []
#
# processing sentence: Commentary
#
# 	Entity pairs:  []
#
# processing sentence: Cartoons
#
# 	Entity pairs:  []
#
# processing sentence: Election Endorsements
#
#
#  Sports
#
#  Sports
#
# 	Entity pairs:  []
#
# processing sentence: San Francisco 49ers
#
# 	Entity pairs:  []
#
# processing sentence: San Francisco Giants
#
# 	Entity pairs:  []
#
# processing sentence: Golden State Warriors
#  Raiders
#
# 	Entity pairs:  []
#
# processing sentence: Oakland Athletics
#
# 	Entity pairs:  []
#
# processing sentence: San Jose Sharks
#
# 	Entity pairs:  []
#
# processing sentence: San Jose Earthquakes
#  College Sports
#
# 	Entity pairs:  []
#
# processing sentence: Pac-12 Hotline
#
# 	Entity pairs:  []
#
# processing sentence: High School Sports
#
# 	Entity pairs:  []
#
# processing sentence: Other Sports
#  Sports Columnists
#  Sports Blogs
#
#
#  Things To Do
# 	Entity pairs:  []
#
# processing sentence:
#
#  Entertainment
#
# 	Entity pairs:  []
#
# processing sentence: Things To Do
#  Restaurants, Food and Drink
#  Celebrities
#  TV Streaming
#
# 	Entity pairs:  []
#
# processing sentence: Movies
#
# 	Entity pairs:  []
#
# processing sentence: Music
#  Theater
#
# 	Entity pairs:  []
#
# processing sentence: Lifestyle
#
# 	Entity pairs:  []
#
# processing sentence: Advice
#
# 	Entity pairs:  []
#
# processing sentence: Travel
#  Pets and Animals
#  Comics
#
# 	Entity pairs:  []
#
# processing sentence: Puzzles and Games
#  Horoscopes
#
# 	Entity pairs:  []
#
# processing sentence: Local Events
#
#
#  Marketplace
#
# 	Entity pairs:  []
#
# processing sentence: Subscribe
#  Log In
#
# 	Entity pairs:  []
#
# processing sentence: Logout
#
# 	Entity pairs:  []
#
# processing sentence: Close Menu
#
#
#
#
#    Skip to content
#
# 	Entity pairs:  []
#
# processing sentence: News
#
#  News
#
# 	Entity pairs:  []
#
# processing sentence: Latest Headlines
#
# 	Entity pairs:  []
#
# processing sentence: Crime and Public Safety
#  Business
#
# 	Entity pairs:  []
#
# processing sentence: Real Estate News
#
# 	Entity pairs:  []
#
# processing sentence: Housing
#  Economy
#
# 	Entity pairs:  []
#
# processing sentence: California News
#
# 	Entity pairs:  []
#
# processing sentence: National News
#  World News
#  Politics
#  Technology
#
# 	Entity pairs:  []
#
# processing sentence: Education
#
# 	Entity pairs:  []
#
# processing sentence: Environment
#
# 	Entity pairs:  []
#
# processing sentence: Science
#  Health
#
# 	Entity pairs:  []
#
# processing sentence: Mr. Roadshow
#
# 	Entity pairs:  []
#
# processing sentence: Obituaries in the News
#  SiliconValley.com
# 	Entity pairs:  []
#
# processing sentence:
#
# 	Entity pairs:  []
#
# processing sentence: Transportation
#
# 	Entity pairs:  []
#
# processing sentence: The Cannifornian
#
#
#  Local
#
#  Local News Map
#  Bay Area
#
# 	Entity pairs:  []
#
# processing sentence: San Jose
#
# 	Entity pairs:  []
#
# processing sentence: Santa Clara County
#  Peninsula
#
# 	Entity pairs:  []
#
# processing sentence: San Mateo County
#  Alameda County
#
# 	Entity pairs:  []
#
# processing sentence: Santa Cruz County
#
# 	Entity pairs:  []
#
# processing sentence: Sal Pizarro
#
# 	Entity pairs:  []
#
# processing sentence: Local Obituaries
#  Place an Obituary
#
#
#  Opinion
#
#  Opinion
#
# 	Entity pairs:  []
#
# processing sentence: Editorials
#
# 	Entity pairs:  []
#
# processing sentence: Opinion Columnists
#  Letters to the Editor
#
# 	Entity pairs:  []
#
# processing sentence: Commentary
#
# 	Entity pairs:  []
#
# processing sentence: Cartoons
#
# 	Entity pairs:  []
#
# processing sentence: Election Endorsements
#
#
#  Sports
#
#  Sports
#
# 	Entity pairs:  []
#
# processing sentence: San Francisco 49ers
#
# 	Entity pairs:  []
#
# processing sentence: San Francisco Giants
#
# 	Entity pairs:  []
#
# processing sentence: Golden State Warriors
#  Raiders
#
# 	Entity pairs:  []
#
# processing sentence: Oakland Athletics
#
# 	Entity pairs:  []
#
# processing sentence: San Jose Sharks
#
# 	Entity pairs:  []
#
# processing sentence: San Jose Earthquakes
#  College Sports
#
# 	Entity pairs:  []
#
# processing sentence: Pac-12 Hotline
#
# 	Entity pairs:  []
#
# processing sentence: High School Sports
#
# 	Entity pairs:  []
#
# processing sentence: Other Sports
#  Sports Columnists
#  Sports Blogs
#
#
#  Things To Do
# 	Entity pairs:  []
#
# processing sentence:
#
#  Entertainment
#
# 	Entity pairs:  []
#
# processing sentence: Things To Do
#  Restaurants, Food and Drink
#  Celebrities
#  TV Streaming
#
# 	Entity pairs:  []
#
# processing sentence: Movies
#
# 	Entity pairs:  []
#
# processing sentence: Music
#  Theater
#
# 	Entity pairs:  []
#
# processing sentence: Lifestyle
#
# 	Entity pairs:  []
#
# processing sentence: Advice
#
# 	Entity pairs:  []
#
# processing sentence: Travel
#  Pets and Animals
#  Comics
#
# 	Entity pairs:  []
#
# processing sentence: Puzzles and Games
#  Horoscopes
#
# 	Entity pairs:  []
#
# processing sentence: Local Events
#
#
#  Marketplace
#
# 	Entity pairs:  []
#
# processing sentence: Subscribe
#  Log In
#
# 	Entity pairs:  []
#
# processing sentence: Logout
#
#
#
#
#
#
#
#
#  63°F
#
#
#
#
#
#
#
#
#  Today’s E Edition
#  Manage Subscription
#
# 	Entity pairs:  []
#
# processing sentence: Sign Up for Newsletters
#
# 	Entity pairs:  []
#
# processing sentence: Logout
#
#
#
#
#
#
#
# 			Megan Rapinoe, World Cup star, has uneasy...
#
#
#
#
# 	Entity pairs:  []
#
# processing sentence: Share this: Click to share on Facebook (Opens in new window) Click to share on Twitter (Opens in new window) Click to print (Opens in new window) Click to share on Reddit (Opens in new window)
#
#
#
#
#
#
#
#
#
# 	Entity pairs:  [(['Click', 'to', 'share', 'on', 'Facebook', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'share', 'on', 'Twitter', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'print', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'share', 'on', 'Reddit', '('], ('Facebook', 'ORGANIZATION', (4, 4)), ('Reddit', 'ORGANIZATION', (35, 35)))]
#
# processing sentence: Trending:
#
#
#
#
#
# 			Storm tracker map
#
#
#
#
#
# 			Giants:
# 	Entity pairs:  []
#
# processing sentence: Wood looks good
#
#
#
#
#
#
# 	Entity pairs:  []
#
# processing sentence: Goodbye KRTY: station sold
#
#
#
#
#
# 			Vallco Mall redevelopment
#
#
#
#
#
# 			Coach K
#
#
#
#
#
# 			How to watch the Oscars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Breaking News
#
#
#
#
# 			Officer shoots person at downtown S.J. restaurant, a block from fatal shooting a half-hour earlier
#
#
#
#
#
#
#  Sports Other Sports News News
# 	Entity pairs:  []
#
# processing sentence: Based on facts, either observed and verified directly by the reporter, or reported and verified from knowledgeable sources.
# 	Entity pairs:  []
#
# processing sentence:
#
#
#
# 			Women’s World Cup:
# 	Entity pairs:  []
#
# processing sentence: Hometown star stirs mixed feelings in California’s Trump country
#
#  Megan Rapinoe is captain of the U.S. World Cup team but not everyone in Redding likes what she has to say Share this: Click to share on Facebook (Opens in new window) Click to share on Twitter (Opens in new window) Click to print (Opens in new window) Click to share on Reddit (Opens in new window)
# 	Entity pairs:  [(['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('California', 'LOCATION', (6, 6)), ('Megan Rapinoe', 'PERSON', (11, 12))), (['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('California', 'LOCATION', (6, 6)), ('the U.S. World Cup', 'ORGANIZATION', (16, 19))), (['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('California', 'LOCATION', (6, 6)), ('Redding', 'LOCATION', (25, 25))), (['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('Megan Rapinoe', 'PERSON', (11, 12)), ('the U.S. World Cup', 'ORGANIZATION', (16, 19))), (['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('Megan Rapinoe', 'PERSON', (11, 12)), ('Redding', 'LOCATION', (25, 25))), (['Hometown', 'star', 'stirs', 'mixed', 'feelings', 'in', 'California', '’s', 'Trump', 'country', '\t\t \n \n ', 'Megan', 'Rapinoe', 'is', 'captain', 'of', 'the', 'U.S.', 'World', 'Cup', 'team', 'but', 'not', 'everyone', 'in', 'Redding', 'likes', 'what', 'she', 'has', 'to', 'say', 'Share', 'this', ':'], ('the U.S. World Cup', 'ORGANIZATION', (16, 19)), ('Redding', 'LOCATION', (25, 25))), (['Click', 'to', 'share', 'on', 'Facebook', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'share', 'on', 'Twitter', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'print', '(', 'Opens', 'in', 'new', 'window', ')', 'Click', 'to', 'share', 'on', 'Reddit', '('], ('Facebook', 'ORGANIZATION', (4, 4)), ('Reddit', 'ORGANIZATION', (35, 35)))]
#
# processing sentence: Megan Rapinoe of the USA looks on during the USA Training Session at Lyon Training Center on July 01, 2019 in Lyon, France.
# 	Entity pairs:  [(['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('USA', 'LOCATION', (4, 4))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('the USA Training Session', 'ORGANIZATION', (8, 11))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Lyon Training Center', 'ORGANIZATION', (13, 15))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Lyon', 'LOCATION', (22, 22))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ',', 'France', '.'], ('Megan Rapinoe', 'PERSON', (0, 1)), ('France', 'LOCATION', (24, 24))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('USA', 'LOCATION', (4, 4)), ('the USA Training Session', 'ORGANIZATION', (8, 11))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('USA', 'LOCATION', (4, 4)), ('Lyon Training Center', 'ORGANIZATION', (13, 15))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ','], ('USA', 'LOCATION', (4, 4)), ('Lyon', 'LOCATION', (22, 22))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ',', 'France', '.'], ('USA', 'LOCATION', (4, 4)), ('France', 'LOCATION', (24, 24))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ','], ('the USA Training Session', 'ORGANIZATION', (8, 11)), ('Lyon Training Center', 'ORGANIZATION', (13, 15))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ','], ('the USA Training Session', 'ORGANIZATION', (8, 11)), ('Lyon', 'LOCATION', (22, 22))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ',', 'France', '.'], ('the USA Training Session', 'ORGANIZATION', (8, 11)), ('France', 'LOCATION', (24, 24))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ','], ('Lyon Training Center', 'ORGANIZATION', (13, 15)), ('Lyon', 'LOCATION', (22, 22))), (['Megan', 'Rapinoe', 'of', 'the', 'USA', 'looks', 'on', 'during', 'the', 'USA', 'Training', 'Session', 'at', 'Lyon', 'Training', 'Center', 'on', 'July', '01', ',', '2019', 'in', 'Lyon', ',', 'France', '.'], ('Lyon Training Center', 'ORGANIZATION', (13, 15)), ('France', 'LOCATION', (24, 24))), (['2019', 'in', 'Lyon', ',', 'France', '.'], ('Lyon', 'LOCATION', (2, 2)), ('France', 'LOCATION', (4, 4)))]
#
# processing sentence: (Photo by Elsa/Getty Images)
# 	Entity pairs:  []
#
# processing sentence: Lassen Peak can be seen in the distance from Redding, Calif., on Thursday, July 4, 2019.
# 	Entity pairs:  [(['Lassen', 'Peak', 'can', 'be', 'seen', 'in', 'the', 'distance', 'from', 'Redding', ','], ('Lassen Peak', 'PERSON', (0, 1)), ('Redding', 'LOCATION', (9, 9))), (['Lassen', 'Peak', 'can', 'be', 'seen', 'in', 'the', 'distance', 'from', 'Redding', ',', 'Calif.', ','], ('Lassen Peak', 'PERSON', (0, 1)), ('Calif.', 'LOCATION', (11, 11))), (['Lassen', 'Peak', 'can', 'be', 'seen', 'in', 'the', 'distance', 'from', 'Redding', ',', 'Calif.', ','], ('Redding', 'LOCATION', (9, 9)), ('Calif.', 'LOCATION', (11, 11)))]
#
# processing sentence: U.S. women's national team winger Megan Rapinoe grew up in Redding.
# 	Entity pairs:  [(['U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'grew', 'up', 'in', 'Redding', '.'], ('U.S.', 'LOCATION', (0, 0)), ('Megan Rapinoe', 'PERSON', (6, 7))), (['U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'grew', 'up', 'in', 'Redding', '.'], ('U.S.', 'LOCATION', (0, 0)), ('Redding', 'LOCATION', (11, 11))), (['U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'grew', 'up', 'in', 'Redding', '.'], ('Megan Rapinoe', 'PERSON', (6, 7)), ('Redding', 'LOCATION', (11, 11)))]
#
# processing sentence:  (Anda Chu/Bay Area News Group)
# 	Entity pairs:  []
#
# processing sentence: Jim Rapinoe the father of U.S. women's national team winger Megan Rapinoe poses for a photograph on the soccer field named after his daughter at the California Soccer Park in Redding, Calif., on Thursday, July 4, 2019.
# 	Entity pairs:  [(['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('U.S.', 'LOCATION', (5, 5))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Megan Rapinoe', 'PERSON', (11, 12))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Redding', 'LOCATION', (31, 31))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Calif.', 'LOCATION', (33, 33))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('U.S.', 'LOCATION', (5, 5)), ('Megan Rapinoe', 'PERSON', (11, 12))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('U.S.', 'LOCATION', (5, 5)), ('Redding', 'LOCATION', (31, 31))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('U.S.', 'LOCATION', (5, 5)), ('Calif.', 'LOCATION', (33, 33))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Megan Rapinoe', 'PERSON', (11, 12)), ('Redding', 'LOCATION', (31, 31))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('Megan Rapinoe', 'PERSON', (11, 12)), ('Calif.', 'LOCATION', (33, 33))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'on', 'the', 'soccer', 'field', 'named', 'after', 'his', 'daughter', 'at', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('Redding', 'LOCATION', (31, 31)), ('Calif.', 'LOCATION', (33, 33)))]
#
# processing sentence: The park is planing to host a World Cup finals watch party on Sunday.
# 	Entity pairs:  []
#
# processing sentence:  (Anda Chu/Bay Area News Group)
# 	Entity pairs:  []
#
# processing sentence: Megan Rapinoe (15) celebrates Alex Morgan's (13) second goal of the game during the 66th minute of the game against France Wednesday July 25, 2012 at legendary Hampden Park in Glasgow, Scotland.
# 	Entity pairs:  [(['Megan', 'Rapinoe', '(', '15', ')', 'celebrates', 'Alex', 'Morgan', "'s", '('], ('Megan Rapinoe', 'PERSON', (0, 1)), ("Alex Morgan's", 'PERSON', (6, 8))), (['Megan', 'Rapinoe', '(', '15', ')', 'celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('France', 'LOCATION', (25, 25))), (['Megan', 'Rapinoe', '(', '15', ')', 'celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ','], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Glasgow', 'LOCATION', (36, 36))), (['Megan', 'Rapinoe', '(', '15', ')', 'celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ',', 'Scotland', '.'], ('Megan Rapinoe', 'PERSON', (0, 1)), ('Scotland', 'LOCATION', (38, 38))), (['celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ','], ("Alex Morgan's", 'PERSON', (1, 3)), ('France', 'LOCATION', (20, 20))), (['celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ','], ("Alex Morgan's", 'PERSON', (1, 3)), ('Glasgow', 'LOCATION', (31, 31))), (['celebrates', 'Alex', 'Morgan', "'s", '(', '13', ')', 'second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ',', 'Scotland', '.'], ("Alex Morgan's", 'PERSON', (1, 3)), ('Scotland', 'LOCATION', (33, 33))), (['second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ','], ('France', 'LOCATION', (13, 13)), ('Glasgow', 'LOCATION', (24, 24))), (['second', 'goal', 'of', 'the', 'game', 'during', 'the', '66th', 'minute', 'of', 'the', 'game', 'against', 'France', 'Wednesday', 'July', '25', ',', '2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ',', 'Scotland', '.'], ('France', 'LOCATION', (13, 13)), ('Scotland', 'LOCATION', (26, 26))), (['2012', 'at', 'legendary', 'Hampden', 'Park', 'in', 'Glasgow', ',', 'Scotland', '.'], ('Glasgow', 'LOCATION', (6, 6)), ('Scotland', 'LOCATION', (8, 8)))]
#
# processing sentence: Though the Olympic Games do not start until Friday, soccer starts early and Cal-grad Morgan shined in her Olympic debut.
# 	Entity pairs:  [(['soccer', 'starts', 'early', 'and', 'Cal', '-', 'grad', 'Morgan', 'shined', 'in', 'her', 'Olympic', 'debut', '.'], ('Cal-grad Morgan', 'ORGANIZATION', (4, 7)), ('Olympic', 'LOCATION', (11, 11)))]
#
# processing sentence: (Karl Mondon/Staff)
# 	Entity pairs:  []
#
# processing sentence: Jim Rapinoe the father of U.S. women's national team winger Megan Rapinoe poses for a photograph along 15 Rapinoe Way named for his daughter near the California Soccer Park in Redding, Calif., on Thursday, July 4, 2019.
# 	Entity pairs:  [(['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('U.S.', 'LOCATION', (5, 5))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Megan Rapinoe', 'PERSON', (11, 12))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Rapinoe Way', 'PERSON', (19, 20))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Redding', 'LOCATION', (31, 31))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('Jim Rapinoe', 'PERSON', (0, 1)), ('Calif.', 'LOCATION', (33, 33))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('U.S.', 'LOCATION', (5, 5)), ('Megan Rapinoe', 'PERSON', (11, 12))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('U.S.', 'LOCATION', (5, 5)), ('Rapinoe Way', 'PERSON', (19, 20))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('U.S.', 'LOCATION', (5, 5)), ('Redding', 'LOCATION', (31, 31))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ',', 'Calif.', ','], ('U.S.', 'LOCATION', (5, 5)), ('Calif.', 'LOCATION', (33, 33))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Megan Rapinoe', 'PERSON', (11, 12)), ('Rapinoe Way', 'PERSON', (19, 20))), (['Jim', 'Rapinoe', 'the', 'father', 'of', 'U.S.', 'women', "'s", 'national', 'team', 'winger', 'Megan', 'Rapinoe', 'poses', 'for', 'a', 'photograph', 'along', '15', 'Rapinoe', 'Way', 'named', 'for', 'his', 'daughter', 'near', 'the', 'California', 'Soccer', 'Park', 'in', 'Redding', ','], ('Megan Rapinoe', 'PERSON', (11, 12)), ('Redding', 'LOCATION', (31, 31))) ...
#
# processing sentence: The park is planing to host a World Cup finals watch party on Sunday.
# 	Entity pairs:  []
#
# processing sentence:  (Anda Chu/Bay Area News Group)
# 	Entity pairs:  []
#
# processing sentence: South Africa's Lebohang Ramalepe (2), left, and United States forward Megan Rapinoe (15), right, go after a ball during the second half of their friendly game at Levi's Stadium in Santa Clara, Calf., on Sunday, May 12, 2019.
# ...
#
# processing sentence: Rapinoe also  credits Bird  with helping her follow a diet and exercise regimen that got her in better shape at that time.
# 	Entity pairs:  []
#
# processing sentence: "I really did transform.
# 	Entity pairs:  []
#
# processing sentence: From a career standpoint, I owe so much to her.
# 	Entity pairs:  []
#
# processing sentence: " The couple moved in together in 2018.
# 	Entity pairs:  []
#
# processing sentence: During the Covid-19 pandemic, Rapinoe joined Bird in the WNBA bubble in Florida in 2020 so the two would not have to be separated.
# 	Entity pairs:  [(['Rapinoe', 'joined', 'Bird', 'in', 'the', 'WNBA', 'bubble', 'in', 'Florida', 'in', '2020', 'so', 'the', 'two', 'would', 'not', 'have', 'to', 'be', 'separated', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('WNBA', 'ORGANIZATION', (5, 5))), (['Rapinoe', 'joined', 'Bird', 'in', 'the', 'WNBA', 'bubble', 'in', 'Florida', 'in', '2020', 'so', 'the', 'two', 'would', 'not', 'have', 'to', 'be', 'separated', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('Florida', 'LOCATION', (8, 8))), (['Rapinoe', 'joined', 'Bird', 'in', 'the', 'WNBA', 'bubble', 'in', 'Florida', 'in', '2020', 'so', 'the', 'two', 'would', 'not', 'have', 'to', 'be', 'separated', '.'], ('WNBA', 'ORGANIZATION', (5, 5)), ('Florida', 'LOCATION', (8, 8)))]
#
# processing sentence: Rapinoe and Bird announced their engagement in October 2020.
# 	Entity pairs:  [(['Rapinoe', 'and', 'Bird', 'announced', 'their', 'engagement', 'in', 'October', '2020', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('Bird', 'PERSON', (2, 2)))]
#
# processing sentence: Media Appearances In 2018, Rapinoe and Bird appeared on the cover of  ESPN The Magazine 's Body Issue, the first openly gay couple to do so.
# 	Entity pairs:  [(['Rapinoe', 'and', 'Bird', 'appeared', 'on', 'the', 'cover', 'of', ' ', 'ESPN', 'The', 'Magazine', "'s", 'Body', 'Issue', ','], ('Rapinoe', 'PERSON', (0, 0)), ('Bird', 'PERSON', (2, 2))), (['Rapinoe', 'and', 'Bird', 'appeared', 'on', 'the', 'cover', 'of', ' ', 'ESPN', 'The', 'Magazine', "'s", 'Body', 'Issue', ','], ('Rapinoe', 'PERSON', (0, 0)), ('ESPN', 'ORGANIZATION', (9, 9))), (['Rapinoe', 'and', 'Bird', 'appeared', 'on', 'the', 'cover', 'of', ' ', 'ESPN', 'The', 'Magazine', "'s", 'Body', 'Issue', ','], ('Bird', 'PERSON', (2, 2)), ('ESPN', 'ORGANIZATION', (9, 9)))]
#
# processing sentence: In 2019, Rapinoe was the first out lesbian to show up in the  Sports Illustrated  Swimsuit Issue.
# 	Entity pairs:  [(['Rapinoe', 'was', 'the', 'first', 'out', 'lesbian', 'to', 'show', 'up', 'in', 'the', ' ', 'Sports', 'Illustrated', ' ', 'Swimsuit', 'Issue', '.'], ('Rapinoe', 'PERSON', (0, 0)), ('Swimsuit', 'PERSON', (15, 15)))]
#
# processing sentence: She was named  Sports Illustrated  Sportsperson of the Year that same year.
# 	Entity pairs:  []
#
# processing sentence: Rapinoe was seen in the 2021 documentary  LFG , about the fight for equal pay for women soccer players.
# 	Entity pairs:  []
#
# processing sentence: Her one-hour special,  Seeing America With Megan Rapinoe , was released in August 2020.
# 	Entity pairs:  []
#
# processing sentence: Rapinoe was also one of the hosts for the ESPYs in 2020 and appeared in the reboot of  The L Word .
# 	Entity pairs:  []
#
# processing sentence: Business Rapinoe has been sponsored by Nike, Samsung and Vitamin Water.
# 	Entity pairs:  [(['Business', 'Rapinoe', 'has', 'been', 'sponsored', 'by', 'Nike', ',', 'Samsung', 'and', 'Vitamin', 'Water', '.'], ('Nike', 'ORGANIZATION', (6, 6)), ('Samsung', 'ORGANIZATION', (8, 8))), (['Business', 'Rapinoe', 'has', 'been', 'sponsored', 'by', 'Nike', ',', 'Samsung', 'and', 'Vitamin', 'Water', '.'], ('Nike', 'ORGANIZATION', (6, 6)), ('Vitamin Water', 'ORGANIZATION', (10, 11))), (['Samsung', 'and', 'Vitamin', 'Water', '.'], ('Samsung', 'ORGANIZATION', (0, 0)), ('Vitamin Water', 'ORGANIZATION', (2, 3)))]
#
# processing sentence: Her endorsement deals range from Schmidt's deodorant to Victoria's Secret.
# 	Entity pairs:  []
#
# processing sentence: The organization Rapinoe SC sets up sports clinics, and Rapinoe co-founded a lifestyle brand called re-inc.
# 	Entity pairs:  [(['The', 'organization', 'Rapinoe', 'SC', 'sets', 'up', 'sports', 'clinics', ',', 'and', 'Rapinoe', 'co', '-'], ('Rapinoe SC', 'ORGANIZATION', (2, 3)), ('Rapinoe', 'PERSON', (10, 10))), (['The', 'organization', 'Rapinoe', 'SC', 'sets', 'up', 'sports', 'clinics', ',', 'and', 'Rapinoe', 'co', '-', 'founded', 'a', 'lifestyle', 'brand', 'called', 're', '-', 'inc', '.'], ('Rapinoe SC', 'ORGANIZATION', (2, 3)), ('re-inc', 'ORGANIZATION', (18, 20))), (['and', 'Rapinoe', 'co', '-', 'founded', 'a', 'lifestyle', 'brand', 'called', 're', '-', 'inc', '.'], ('Rapinoe', 'PERSON', (1, 1)), ('re-inc', 'ORGANIZATION', (9, 11)))]
#
# processing sentence: Fact Check We strive for accuracy and fairness.
# 	Entity pairs:  []
#
# processing sentence: If you see something that doesn't look right,  contact us !
# 	Entity pairs:  []
#
# processing sentence: Citation Information Article Title Megan Rapinoe Biography Author Biography.com Editors Website Name The Biography.com website URL https://www.biography.com/athlete/megan-rapinoe
# 	Entity pairs:  [(['Citation', 'Information', 'Article', 'Title', 'Megan', 'Rapinoe', 'Biography', 'Author', 'Biography.com', 'Editors', 'Website', 'Name', 'The', 'Biography.com', 'website', 'URL', 'https://www.biography.com/athlete/megan-rapinoe'], ('Megan Rapinoe Biography', 'PERSON', (4, 6)), ('Biography.com', 'ORGANIZATION', (13, 13))), (['Citation', 'Information', 'Article', 'Title', 'Megan', 'Rapinoe', 'Biography', 'Author', 'Biography.com', 'Editors', 'Website', 'Name', 'The', 'Biography.com', 'website', 'URL', 'https://www.biography.com/athlete/megan-rapinoe'], ('Megan Rapinoe Biography', 'PERSON', (4, 6)), ('URL https://www.biography.com/athlete/megan-rapinoe', 'ORGANIZATION', (15, 16))), (['Citation', 'Information', 'Article', 'Title', 'Megan', 'Rapinoe', 'Biography', 'Author', 'Biography.com', 'Editors', 'Website', 'Name', 'The', 'Biography.com', 'website', 'URL', 'https://www.biography.com/athlete/megan-rapinoe'], ('Biography.com', 'ORGANIZATION', (13, 13)), ('URL https://www.biography.com/athlete/megan-rapinoe', 'ORGANIZATION', (15, 16)))]
#
# processing sentence: Access Date Publisher A&E Television Networks
# 	Entity pairs:  []
#
# processing sentence: Last Updated August 2, 2021 Original Published Date August 2, 2021 Comment BIOGRAPHY NEWSLETTER Subscribe to the Biography newsletter to receive stories about the people who shaped our world and the stories that shaped their lives.
# 	Entity pairs:  []
#
# processing sentence: SIGN UP MORE STORIES FROM BIOGRAPHY  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Alex Morgan Soccer player Alex Morgan has starred for the U.S. national teams that won Olympic gold and the FIFA Women's World Cup.
# 	Entity pairs:  [(['main.js', 'Person', 'Alex', 'Morgan', 'Soccer', 'player', 'Alex', 'Morgan', 'has', 'starred', 'for', 'the', 'U.S.', 'national', 'teams', 'that', 'won', 'Olympic', 'gold', 'and', 'the', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('Alex Morgan', 'PERSON', (2, 3)), ('U.S.', 'LOCATION', (12, 12))), (['main.js', 'Person', 'Alex', 'Morgan', 'Soccer', 'player', 'Alex', 'Morgan', 'has', 'starred', 'for', 'the', 'U.S.', 'national', 'teams', 'that', 'won', 'Olympic', 'gold', 'and', 'the', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('Alex Morgan', 'PERSON', (2, 3)), ("the FIFA Women's", 'ORGANIZATION', (20, 23))), (['main.js', 'Person', 'Alex', 'Morgan', 'Soccer', 'player', 'Alex', 'Morgan', 'has', 'starred', 'for', 'the', 'U.S.', 'national', 'teams', 'that', 'won', 'Olympic', 'gold', 'and', 'the', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('Alex Morgan', 'PERSON', (6, 7)), ('U.S.', 'LOCATION', (12, 12))), (['main.js', 'Person', 'Alex', 'Morgan', 'Soccer', 'player', 'Alex', 'Morgan', 'has', 'starred', 'for', 'the', 'U.S.', 'national', 'teams', 'that', 'won', 'Olympic', 'gold', 'and', 'the', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('Alex Morgan', 'PERSON', (6, 7)), ("the FIFA Women's", 'ORGANIZATION', (20, 23))), (['main.js', 'Person', 'Alex', 'Morgan', 'Soccer', 'player', 'Alex', 'Morgan', 'has', 'starred', 'for', 'the', 'U.S.', 'national', 'teams', 'that', 'won', 'Olympic', 'gold', 'and', 'the', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('U.S.', 'LOCATION', (12, 12)), ("the FIFA Women's", 'ORGANIZATION', (20, 23)))]
#
# processing sentence: (1989–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Hope Solo Hope Solo proved to be one of the world's top goalkeepers while helping the U.S. women's soccer team win two Olympic gold medals and the 2015 FIFA Women's World Cup.
# 	Entity pairs:  [(['main.js', 'Person', 'Hope', 'Solo', 'Hope', 'Solo', 'proved', 'to', 'be', 'one', 'of', 'the', 'world', "'s", 'top', 'goalkeepers', 'while', 'helping', 'the', 'U.S.', 'women', "'s", 'soccer', 'team', 'win', 'two', 'Olympic', 'gold', 'medals', 'and', 'the', '2015', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('U.S.', 'LOCATION', (19, 19)), ('Olympic', 'LOCATION', (26, 26))), (['main.js', 'Person', 'Hope', 'Solo', 'Hope', 'Solo', 'proved', 'to', 'be', 'one', 'of', 'the', 'world', "'s", 'top', 'goalkeepers', 'while', 'helping', 'the', 'U.S.', 'women', "'s", 'soccer', 'team', 'win', 'two', 'Olympic', 'gold', 'medals', 'and', 'the', '2015', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('U.S.', 'LOCATION', (19, 19)), ("FIFA Women's", 'ORGANIZATION', (32, 34))), (['main.js', 'Person', 'Hope', 'Solo', 'Hope', 'Solo', 'proved', 'to', 'be', 'one', 'of', 'the', 'world', "'s", 'top', 'goalkeepers', 'while', 'helping', 'the', 'U.S.', 'women', "'s", 'soccer', 'team', 'win', 'two', 'Olympic', 'gold', 'medals', 'and', 'the', '2015', 'FIFA', 'Women', "'s", 'World', 'Cup', '.'], ('Olympic', 'LOCATION', (26, 26)), ("FIFA Women's", 'ORGANIZATION', (32, 34)))]
#
# processing sentence: (1981–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Michelle Kwan Michelle Kwan is a five-time world champion figure skater and two-time Olympic medalist.
# 	Entity pairs:  []
#
# processing sentence: (1980–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Allyson Felix American runner Allyson Felix has won nine Olympic medals, making her the most decorated woman in U.S.  track and field history.
# 	Entity pairs:  [(['main.js', 'Person', 'Allyson', 'Felix', 'American', 'runner', 'Allyson', 'Felix', 'has', 'won', 'nine', 'Olympic', 'medals', ',', 'making', 'her', 'the', 'most', 'decorated', 'woman', 'in', 'U.S.', ' ', 'track', 'and', 'field', 'history', '.'], ('Allyson Felix', 'PERSON', (2, 3)), ('U.S.', 'LOCATION', (21, 21))), (['main.js', 'Person', 'Allyson', 'Felix', 'American', 'runner', 'Allyson', 'Felix', 'has', 'won', 'nine', 'Olympic', 'medals', ',', 'making', 'her', 'the', 'most', 'decorated', 'woman', 'in', 'U.S.', ' ', 'track', 'and', 'field', 'history', '.'], ('Allyson Felix', 'PERSON', (6, 7)), ('U.S.', 'LOCATION', (21, 21)))]
#
# processing sentence: (1985–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Mia Hamm Mia Hamm is a former American soccer player who competed with the U.S. women's national soccer team for 17 years.
# 	Entity pairs:  [(['main.js', 'Person', 'Mia', 'Hamm', 'Mia', 'Hamm', 'is', 'a', 'former', 'American', 'soccer', 'player', 'who', 'competed', 'with', 'the', 'U.S.', 'women', "'s", 'national', 'soccer', 'team', 'for', '17', 'years', '.'], ('Mia Hamm', 'PERSON', (2, 3)), ('U.S.', 'LOCATION', (16, 16)))]
#
# processing sentence: She won the Women's World Cup in 1991 and 1999, and took Olympic gold medals in 1996 and 2004.
# 	Entity pairs:  []
#
# processing sentence: (1972–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Michael Phelps Swimmer Michael Phelps has set the record for winning the most medals, 28, of any Olympic athlete in history.
# 	Entity pairs:  []
#
# processing sentence: (1985–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Serena Williams American professional tennis player Serena Williams has won 23 Grand Slam singles titles and several Olympic gold medals.
# 	Entity pairs:  []
#
# processing sentence: (1981–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Lindsey Vonn American alpine skier Lindsey Vonn, a 2010 Olympic gold medalist, has won four World Cup overall titles and owns the record for most World Cup wins by a woman.
# 	Entity pairs:  []
#
# processing sentence: (1984–)  !
# 	Entity pairs:  []
#
# processing sentence: when modifying attributes of this phoenix-super-link, make sure you also set attributes in superLink in card/main.js Person Lisa Leslie Lisa Leslie was an All-Star basketball player, Olympic gold medalist and WNBA league MVP.
# 	Entity pairs:  [(['main.js', 'Person', 'Lisa', 'Leslie', 'Lisa', 'Leslie', 'was', 'an', 'All', '-', 'Star', 'basketball', 'player', ',', 'Olympic', 'gold', 'medalist', 'and', 'WNBA', 'league', 'MVP', '.'], ('Lisa Leslie Lisa Leslie', 'PERSON', (2, 5)), ('WNBA', 'ORGANIZATION', (18, 18))), (['main.js', 'Person', 'Lisa', 'Leslie', 'Lisa', 'Leslie', 'was', 'an', 'All', '-', 'Star', 'basketball', 'player', ',', 'Olympic', 'gold', 'medalist', 'and', 'WNBA', 'league', 'MVP', '.'], ('Lisa Leslie Lisa Leslie', 'PERSON', (2, 5)), ('MVP', 'ORGANIZATION', (20, 20))), (['Olympic', 'gold', 'medalist', 'and', 'WNBA', 'league', 'MVP', '.'], ('WNBA', 'ORGANIZATION', (4, 4)), ('MVP', 'ORGANIZATION', (6, 6)))]
#
# processing sentence: (1972–) Loading...
# 	Entity pairs:  []
#
# processing sentence: See More About Contact Us
# 	Entity pairs:  []
#
# processing sentence: Advertise Privacy Notice Terms of Use Copyright Policy Ad Choices Accessibility Support © 2022 Biography and the Biography logo are registered trademarks of A&E Television Networks, LLC.
# 	Entity pairs:  [(['Advertise', 'Privacy', 'Notice', 'Terms', 'of', 'Use', 'Copyright', 'Policy', 'Ad', 'Choices', 'Accessibility', 'Support', '©', '2022', 'Biography', 'and', 'the', 'Biography', 'logo', 'are', 'registered', 'trademarks', 'of', 'A&E', 'Television', 'Networks', ','], ('Biography', 'PERSON', (17, 17)), ('A&E Television Networks', 'ORGANIZATION', (23, 25))), (['Advertise', 'Privacy', 'Notice', 'Terms', 'of', 'Use', 'Copyright', 'Policy', 'Ad', 'Choices', 'Accessibility', 'Support', '©', '2022', 'Biography', 'and', 'the', 'Biography', 'logo', 'are', 'registered', 'trademarks', 'of', 'A&E', 'Television', 'Networks', ',', 'LLC', '.'], ('Biography', 'PERSON', (17, 17)), ('LLC', 'ORGANIZATION', (27, 27))), (['Advertise', 'Privacy', 'Notice', 'Terms', 'of', 'Use', 'Copyright', 'Policy', 'Ad', 'Choices', 'Accessibility', 'Support', '©', '2022', 'Biography', 'and', 'the', 'Biography', 'logo', 'are', 'registered', 'trademarks', 'of', 'A&E', 'Television', 'Networks', ',', 'LLC', '.'], ('A&E Television Networks', 'ORGANIZATION', (23, 25)), ('LLC', 'ORGANIZATION', (27, 27)))]
#
# processing sentence: CLOSE CLOSE CLOSE CLOSE  Template for the recommended content widget
# 	Entity pairs:  []
#
# Finish processing webpage: https://www.biography.com/athlete/megan-rapinoe
# Current X: [{'confidence': 0.990639, 'subject': 'rapinoe', 'object': 'redding'}, {'confidence': 0.7735803, 'subject': 'rapinoe', 'object': 'california'}]
# Current number of relations: 2
